# %%
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI

import requests, dotenv, bs4, openai

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
openai = OpenAI()

message = "Hello, GPT! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": message}
    ]
)
print(response.choices[0].message.content)
# Out:
# Hello! It's great to hear from you! How can I assist you today?

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://www.leelakrishna.online/")
print(ed.title)
print(ed.text)
# Out:
# Leela Krishna Sarepalli
# Menu
# About
# Download My Resume
# Hello, I'm Leela Krishna Sarepalli
# I build tech solutions
# that streamline,
# automate, and
# drive results.
# <!--!  Atomicons Free 1.00 by @atisalab License - https://atomicons.com/license/ (Icons: CC BY 4.0) Copyright 2021 Atomicons -->
# Scroll for more
# About Me
# IT expert, delivering tech solutions through analysis, automation, and leadership.
# Results-driven IT professional with over 10 years of cross-functional experience delivering technology-driven solutions across the U.S. healthcare and financial capital markets. Adept at aligning business goals with innovative technical strategies, I specialize in identifying operational inefficiencies and translating complex business needs into scalable, actionable technology initiatives. I have consistently led the end-to-end delivery of projects—managing budgets, timelines, and stakeholder expectations—while ensuring alignment with regulatory and compliance frameworks such as HIPAA.
# As a Consultant, I empower small businesses through tailored digital solutions using no-code/low-code tools like n8n and RPA platforms such as Power Automate and UiPath. I build scalable workflows, AI-powered chatbots, and automation systems that streamline sales, customer support, and operations. Integrations span Slack, HubSpot, OpenAI, and more—enabling intelligent data processing, lead management, and real-time insights through executive summaries, OCR, and GPT-powered automation.
# Recognized for delivering robust business analysis, process optimization, and comprehensive documentation, including BRDs, FRDs, user stories, and workflows. I bring strong facilitation skills to the table, leading cross-functional teams in stakeholder discovery sessions, JAD meetings, UAT coordination, and change management initiatives. My consultative approach and ability to bridge the gap between technical teams and business units have contributed to the successful implementation of enterprise applications, integrations, and cloud migrations.
# Specialized in quality engineering, test automation framework design, and DevOps implementation with hands-on experience using modern tools and practices. I have developed and maintained automated testing pipelines using Selenium, Postman, and other open-source tools, ensuring continuous integration and deployment (CI/CD) in fast-paced environments. Whether operating within traditional Waterfall models or adapting to Agile and Hybrid frameworks, I bring a flexible, structured approach that promotes collaboration, transparency, and high-quality delivery at scale.
# More About Me
# Why Work With Me
# Videos
# See my work in action
# AI Appointment Scheduler
# — an automated, voice-first booking system powered by Vapi.ai, seamlessly integrated with Google Calendar & Sheets.
# Callers can schedule appointments entirely through natural conversation — the AI collects their info, checks availability, books the slot, and logs everything automatically.
# No manual steps, no double-bookings — just pure workflow magic.
# Microsoft Power Platform Demo
# — How can you make a bigger impact without a big tech team?
# In this demo, I walk through how Animal Shelter uses low-code tools to manage data in Dataverse, build apps in Power Apps, automate communication using Power Automate, and visualize success stories in Power BI.
# See how data, automation, and insights help teams work smarter and drive meaningful change.
# AI Personal Assistant with n8n
# — Ever realize how much you can automate without touching a single line of code?
# Low-code and no-code tools like n8n are changing the game. I built my own AI Personal Assistant inside Telegram that connects apps, handles schedules, sends emails, and posts content on X.
# Personal productivity isn't about doing more — it's about letting automation do the boring stuff for you.
# Rethinking How Systems Talk
# — with MCP and LLMs.
# Model Context Protocol (MCP) acts as a bridge between LLMs and your tools, APIs, or local files. I built an MCP server that identifies skill or experience gaps in your resume when compared with a job description.
# This is just a glimpse of what's coming — when LLMs stop being just chatbots and start becoming system collaborators.
# Experience & Expertise
# My background and skill set
# Project Manager, PMILOC Mississauga (Feb 2025 – Till Date)
# •	Published content to provide real-time PMI events and benefits insights into 4,000+ memberships, monthly events, and overall member engagement.
# •	Automated the event posting and member registration process, optimizing workflows for events, weekly newsletters, reducing manual effort by 50%.
# Business Analyst, YWCA Kitchener-Waterloo (Oct 2024 – Nov 2024)
# •	Gathered requirements from YWCA HR to identify needs for transitioning from paper-based processes to Avanti HCM cloud solutions.
# •	Designed and documented business workflows, use cases, and process flows reducing process inefficiencies by 40%.
# •	Utilized Power Automate for workflow automation, enhancing operational efficiency, reducing manual intervention, and improving response times.
# Business Analyst, VeroSource IT solutions (May 2022 - Aug 2022)
# •	Streamlined the SR&ED process for agile teams, reducing claim preparation time by at least 50% through the development of optimized strategies that increased claim approval chances during technical audits.
# •	Conducted in-depth research on SR&ED eligibility, resulting in accurate documentation that contributed to a 100% coverage of activities claimed during the internship period.
# •	Developed strategies to help teams navigate CRA audits, reducing the likelihood of rejections and ensuring that all claims met technical requirements, achieving a 95% success rate in claim survival.
# •	Skilled in Stakeholder Management. Coordinated SR&ED claim processes, working with leadership, the CRA SR&ED review team, and development teams, leading to the successful approval of the SR&ED claim within.
# •	Engaged with technical and management teams, enhancing cross-functional collaboration and ensuring timely submissions of SR&ED documentation.
# IT Project Manager, Implithoughts IT solutions (Jul 2018 - Jul 2021)
# •	Led the development of Web, IOS and Android applications for retail businesses, successfully launching first version of apps within 2 weeks to fully functional in 2 months, achieving a 95% project completion rate on time and within budget.
# •	Enhanced the UI/UX of applications by closely working with UX designers and UI developers, leading to a 20% improvement in user experience and customer satisfaction, validated through application demos and user feedback with each deployment.
# •	Collaborated with Product Managers and scrum teams to define QA strategy for user stories, ensuring proper test coverage and execution in every sprint.
# •	Facilitated 50+ Agile ceremonies (sprint planning, retrospectives, and demos) using Jira and Azure DevOps, improving team velocity by 20% and fostering collaboration.
# •	Ensured product enhancements align with technical specifications, software architecture and data requirements.
# •	Performed code reviews to ensure software quality, address software defects, and maintain adherence to established development standards.
# •	Managed recruitment, training and allocation of fulltime employees for projects in the organization, achieving a 100% project staffing and optimal resource management.
# Senior Software Engineer, UnitedHealth Group (May 2013 - Jun 2018)
# •	Developed test automation frameworks using Selenium, UFT, and TestNG, achieving 90% test coverage, reducing manual testing efforts, and accelerating release cycles.
# •	Automated Web Accessibility WCAG 2.0 and 508 compliance testing using AXE Chrome, JAWS, and NVDA, ensuring 100% compliance for all new features.
# •	Implemented cross-browser and mobile testing for web and mobile applications using cloud-based platforms like Perfecto IOS/Android and Sauce Labs, achieving 100% test coverage across key operating systems and browsers.
# •	Conducted functional testing, UAT, and business test case development using Postman and SOAP UI, reducing defects by 30% and ensuring high-quality software releases.
# •	Integrated automated testing workflows into CI/CD pipelines using Jenkins and GitLab, reducing testing cycle times by 40%, improving efficiency in software deployment.
# •	Provided technical reviews and audit reports using JIRA, ensuring compliance with industry standards, enhancing regulatory adherence and product reliability.
# IT Quality Analyst, Broadridge Financial Solutions (Jan 2009 - Apr 2013)
# •	Created a comprehensive automation plan for smoke and regression test cases and developed automation suites for sub-functional areas, reducing manual testing efforts by 90% and saving 160 hours for a 3-month release in perpetuity.
# •	Expanded test coverage, provided management with high-level reports, and delivered actionable insights to testers, improving release quality and test scripts.
# •	Produced reusable automation scripts and executed automation suites during product releases, achieving a 95% success rate in defect resolution by analyzing logs and addressing defects within two weeks of each release.
# •	Trained cross-functional teams on utilizing test automation scripts and frameworks, offering technical guidance on automation design and training sessions for all Broadridge QA teams.
# Download My Resume
# Tools & Technology
# 2024 and 2025 have been incredible years of growth, thanks to the amazing tools and technologies I’ve worked with.
# No-Code / Low-Code Development & Workflow Automation
# •	Designed and deployed agentic workflows using n8n and MCP server orchestration, integrating tools such as Slack, HubSpot, Google Workspace, Stripe, and OpenAI.
# •	Developed end-to-end Lead-to-Close Sales Pipelines, automating lead capture, CRM updates, AI-personalized outreach (ChatGPT), and follow-ups via WhatsApp.
# •	Built AI-Enhanced Customer Support Bots connected to systems like Zendesk, enabling smart triage, routing, and AI-generated responses.
# •	Created Daily Executive Summary Generators by consolidating inputs from Notion, Google Sheets, and Jira, summarizing with GPT-4, and delivering insights via email or Teams.
# Digital Transformation & RPA Implementation
# •	Led digital transformation initiatives using Microsoft Power Automate, UiPath, and Automation Anywhere—implementing workflow automation, virtual AI agents, and cross-platform integrations.
# •	Automated document processing using AI Builder and UiPath Document Understanding, extracting structured data from emails, PDFs, invoices, and forms to reduce manual entry and improve data accuracy.
# •	Designed and deployed AI-Driven Chatbots & Virtual Agents using Power Virtual Agents and ChatGPT, integrated with CRMs, helpdesk systems, and communication platforms (Teams, WhatsApp, Slack) to handle customer queries, qualify leads, schedule appointments, and trigger backend actions via APIs.
# My pre-COVID journey included hands-on roles in both software development and quality engineering, setting a strong foundation for what followed.
# •	Developed and maintained automated testing frameworks using Selenium, Postman, and Cypress, ensuring continuous integration and deployment (CI/CD) in Agile environments.
# •	Designed and implemented test automation pipelines for web applications, APIs, and microservices, improving test coverage and reducing regression testing time by 70%.
# •	Implemented DevOps practices using Azure DevOps, GitHub Actions, and Jenkins, automating build, test, and deployment processes to enhance software delivery speed and reliability.
# •	Conducted comprehensive quality assurance testing, including functional, regression, performance, and security testing, ensuring high-quality software releases.
# LinkedIn
# Facebook
# Instagram
# GitHub
# github
# <!--!  Atomicons Free 1.00 by @atisalab License - https://atomicons.com/license/ (Icons: CC BY 4.0) Copyright 2021 Atomicons -->

# %%
# Define our system prompt

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
def summarize(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

summarize("https://www.leelakrishna.online/")
# Out:
# "# Summary of Leela Krishna Sarepalli's Website\n\nLeela Krishna Sarepalli is an IT expert dedicated to creating technology solutions that enhance operational efficiency and business automation. With over 10 years of experience in technology delivery across healthcare and financial markets, he specializes in aligning business goals with innovative technical strategies. Leela empowers small businesses through no-code/low-code tools and automation solutions, ensuring comprehensive project management and regulatory compliance.\n\n### Key Offerings\n- **Automation Solutions:** Development of AI-powered systems, chatbots, and tailored digital solutions.\n- **Project Management:** Comprehensive management of project delivery, including budget and timeline adherence.\n- **Consultative Approach:** Bridging the gap between technical teams and business units for successful project implementation.\n\n### Notable Projects\n- **AI Appointment Scheduler:** An automated scheduling solution utilizing natural language processing.\n- **Microsoft Power Platform Demonstration:** Showcasing automation of data management and communication for organizations using low-code tools.\n- **AI Personal Assistant:** Built within Telegram to automate scheduling and communication tasks without coding.\n\n### Experience Highlights\n- **Project Manager** and **Business Analyst** roles with organizations like PMILOC and YWCA, focusing on optimizing processes and digital solutions.\n- **Senior Software Engineer** with UnitedHealth Group, enhancing test automation frameworks, ensuring compliance, and conducting quality assurance testing.\n\n### Tools & Technologies\nLeela has a robust background in no-code/low-code development, digital transformation, and automation implementation using leading tools like Microsoft Power Automate, UiPath, and various automation testing tools.\n\nFor a detailed view of his projects and expertise, users can download his resume directly from the site."

# %%
# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

display_summary("https://www.leelakrishna.online/")
# Out:
# # Summary of Leela Krishna Sarepalli's Website
#
# Leela Krishna Sarepalli is an IT expert with over 10 years of experience, specializing in delivering technology solutions in the healthcare and financial sectors. The website showcases his skills in streamlining operations through analysis, automation, and leadership.
#
# ## Professional Overview
# - **Expertise:** Technology-driven solutions, operational efficiency, project management, business analysis, DevOps, and quality engineering.
# - **Consulting Services:** Offers tailored digital solutions for small businesses using no-code/low-code tools and various automation platforms.
# - **Project Experience:** Notable roles in project management and business analysis, contributing to significant workflow optimizations and successful project completions.
#
# ## Featured Projects
# - **AI Appointment Scheduler:** A voice-first booking system that integrates with Google Calendar, allowing users to schedule appointments through natural conversation.
# - **Microsoft Power Platform Demo:** Illustrates the use of low-code tools to enhance data management and automations for organizations like Animal Shelter.
# - **AI Personal Assistant:** An automation solution created using n8n to streamline personal productivity by handling tasks without coding.
#
# ## Skills and Tools
# - Proficient in various modern tools, including:
#   - No-Code / Low-Code Development (n8n, Microsoft Power Automate)
#   - DevOps Practices (Azure DevOps, Jenkins)
#   - Test Automation Frameworks (Selenium, Postman)
#
# ## Experience Highlights
# - **Project Manager at PMILOC:** Enhanced member engagement by automating processes.
# - **Business Analyst at YWCA:** Transitioned manual processes to cloud solutions, achieving significant efficiency gains.
# - **Senior Software Engineer at UnitedHealth Group:** Focused on test automation and quality assurance, achieving high test coverage and software release quality.
#
# The website is designed to showcase Leela Krishna Sarepalli's extensive experience, technical expertise, and successful project outcomes, establishing him as a knowledgeable consultant in the tech solutions space.

# %%
# Constants

OLLAMA_API = "http://127.0.0.1:11434/api/chat"
HEADERS = {"Content-Type": "application/json"}
MODEL = "llama3.2"

# %%
messages = [
    {"role": "user", "content": "Describe some of the business applications of Generative AI"}
]
payload = {
        "model": MODEL,
        "messages": messages,
        "stream": False
    }
response = requests.post(OLLAMA_API, json=payload, headers=HEADERS)
print(response.json()['message']['content'])
# Out:
# Generative AI has numerous business applications across various industries, including:
#
# 1. **Content Creation**: AI can generate high-quality content such as blog posts, social media posts, product descriptions, and more. This helps businesses save time and resources while maintaining consistency in their content.
# 2. **Marketing Automation**: Generative AI can create personalized marketing campaigns, automate email marketing, and even generate social media ads.
# 3. **Product Design and Development**: AI can assist in designing new products, generating prototypes, and optimizing product features.
# 4. **Customer Service Chatbots**: Generative AI can power chatbots that can understand customer queries, provide responses, and even resolve issues.
# 5. **Data Analysis and Visualization**: AI can analyze large datasets, identify patterns, and generate visualizations to help businesses make data-driven decisions.
# 6. **Supply Chain Optimization**: Generative AI can optimize supply chain operations, predict demand, and recommend inventory management strategies.
# 7. **Financial Modeling and Forecasting**: AI can generate financial models, forecast revenue, and identify potential risks for businesses.
# 8. **Digital Forensics**: Generative AI can analyze digital evidence, reconstruct events, and help investigators solve crimes.
# 9. **Cybersecurity Threat Analysis**: AI can detect and analyze cyber threats in real-time, helping businesses protect their networks and systems.
# 10. **Innovation and R&D**: Generative AI can assist researchers in generating new ideas, simulating experiments, and optimizing processes.
#
# Specific industries that are leveraging generative AI include:
#
# 1. **Advertising and Media**: Using AI to generate personalized ads and content.
# 2. **E-commerce**: Using AI to optimize product recommendations, pricing, and inventory management.
# 3. **Healthcare**: Using AI to analyze medical images, generate diagnostic reports, and develop new treatments.
# 4. **Finance**: Using AI to generate financial models, forecast revenue, and identify potential risks.
# 5. **Retail**: Using AI to optimize store layouts, predict demand, and personalize customer experiences.
#
# These are just a few examples of the many business applications of generative AI. As the technology continues to evolve, we can expect to see even more innovative uses across various industries.

# %%
import ollama

# %%
def newsummarize(url):
    website = Website(url)
    response = ollama.chat(
        model = MODEL,
        messages = messages_for(website)
    )
    return response['message']['content']

newsummarize("https://www.leelakrishna.online/")
# Out:
# "**Summary of Leela Krishna Sarepalli's Website**\n\nLeela Krishna Sarepalli is an IT expert and consultant who builds tech solutions to streamline, automate, and drive results. With over 10 years of experience in the industry, she delivers technology-driven solutions across various sectors.\n\n**News and Announcements: None found**\n\n**Key Skills and Expertise**\n\n* IT consulting\n* Project management\n* Business analysis\n* Quality engineering\n* Test automation framework design\n* DevOps implementation\n* Low-code/No-code development and workflow automation\n* Digital transformation and RPA implementation\n\n**Recent Experience**\n\nAs a consultant, Leela works with small businesses to deliver tailored digital solutions using no-code/low-code tools like n8n and RPA platforms. She specializes in building scalable workflows, AI-powered chatbots, and automation systems that streamline sales, customer support, and operations.\n\nLeela has also worked on various projects, including:\n\n* Developing an automated booking system powered by Vapi.ai\n* Creating a Microsoft Power Platform demo for an animal shelter\n* Building an AI Personal Assistant using n8n\n* Leading digital transformation initiatives using Microsoft Power Automate, UiPath, and Automation Anywhere\n\n**Tools and Technology**\n\nLeela is familiar with various tools and technologies, including:\n\n* No-Code/Low-Code development platforms like n8n, MCP server, and Power Automate\n* Digital transformation and RPA implementation tools like UiPath and Automation Anywhere\n* Cloud-based platforms like Microsoft Power Apps, Slack, HubSpot, Google Workspace, Stripe, and OpenAI\n\n**Certifications and Expertise**\n\nLeela is a certified Project Manager (PMILOC) and has experience in various areas, including:\n\n* Business analysis\n* Quality engineering\n* Test automation framework design\n* DevOps implementation"

# %%
def display_summary(url):
    summary = newsummarize(url)
    display(Markdown(summary))

display_summary("https://www.leelakrishna.online/")
# Out:
# **Summary of Leela Krishna Sarepalli's Website**
#
# Leela Krishna Sarepalli is an IT expert with over 10 years of experience delivering technology-driven solutions across the U.S. healthcare and financial capital markets. She specializes in streamlining, automating, and driving results through analysis, automation, and leadership.
#
# **News/Announcements:**
#
# * Leela has built a voice-first booking system called AI Appointment Scheduler using Vapi.ai, integrated with Google Calendar & Sheets.
# * A Microsoft Power Platform Demo showcasing how low-code tools can help teams work smarter and drive meaningful change.
#
# **Expertise:**
#
# * IT Project Manager
# * Business Analyst
# * Consultant
# * Quality Engineer
# * DevOps Implementation
#
# **Tools & Technology:**
#
# * No-Code / Low-Code Development
# * Workflow Automation
# * Digital Transformation
# * RPA (Robotic Process Automation)
# * AI and Machine Learning (MCP, LLMs, GPT-4)
#
# **Projects and Experience:**
#
# Leela has worked on various projects, including:
#
# * Implementing digital transformation initiatives using Microsoft Power Automate, UiPath, and Automation Anywhere.
# * Developing automated workflows using n8n and MCP server orchestration.
# * Creating AI-enhanced customer support bots connected to systems like Zendesk.
# * Building daily executive summary generators using Notion, Google Sheets, and Jira.
#
# **Certifications and Education:**
#
# Although not mentioned on the website, Leela's background and expertise imply that she has a strong foundation in IT and related fields.
